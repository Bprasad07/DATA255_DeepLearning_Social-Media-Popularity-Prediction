# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras.layers import Dense, BatchNormalization, Dropout, Add, Concatenate, Embedding, Flatten, Input, MultiHeadAttention
from tensorflow.keras.layers import Add, BatchNormalization
from tensorflow.keras.models import Model
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, Callback
from scipy.stats import spearmanr
import os

# Load data
os.chdir('../data/final/')
X_image = np.load('image_embeddings.npy')
X_text = np.load('text_embeddings.npy')
df = pd.read_csv('data_modeling_features_n_target.csv')
# Out:
# WARNING:tensorflow:From c:\Users\31405.ISBDOMAIN1\AppData\Local\miniconda3\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
df.drop(columns=['image', 'Pid', 'Uid'], inplace=True)
df['Category'] = df['Category'].astype('str')
df['Subcategory'] = df['Subcategory'].astype('str')
df['Concept'] = df['Concept'].astype('category')
y = df['label'].values
numerical_features = ['ispro', 'canbuypro', 'photo_count', 'timezone_timezone_id', 'timezone_offset', 'groups', 'group_impact', 'group_weight', 'year', 'month', 'day', 'hour', 'dayofweek']
X_numerical = df[numerical_features].values

# One-hot encoding for 'Category'
category_enc = OneHotEncoder(sparse=False)
X_category = category_enc.fit_transform(df[['Category']])

# Tokenizing 'SubCategory' and 'Concept'
tokenizer_subcat = Tokenizer()
tokenizer_subcat.fit_on_texts(df['Subcategory'])
X_subcategory = pad_sequences(tokenizer_subcat.texts_to_sequences(df['Subcategory']), maxlen=1)

tokenizer_concept = Tokenizer()
tokenizer_concept.fit_on_texts(df['Concept'].astype(str))
X_concept = pad_sequences(tokenizer_concept.texts_to_sequences(df['Concept'].astype(str)), maxlen=1)

subcategory_vocab_size = len(tokenizer_subcat.word_index) + 1
concept_vocab_size = len(tokenizer_concept.word_index) + 1
subcategory_embedding_dim = int(np.sqrt(subcategory_vocab_size))
concept_embedding_dim = int(np.sqrt(concept_vocab_size))
# Out:
# c:\Users\31405.ISBDOMAIN1\AppData\Local\miniconda3\Lib\site-packages\sklearn\preprocessing\_encoders.py:975: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %%
input_img = Input(shape=(1000,), name='img_input')
input_text = Input(shape=(384,), name='text_input')
input_num = Input(shape=(X_numerical.shape[1],), name='num_input')
input_category = Input(shape=(X_category.shape[1],), name='category_input')
input_subcategory = Input(shape=(1,), name='subcategory_input')
input_concept = Input(shape=(1,), name='concept_input')

subcategory_embedding = Embedding(subcategory_vocab_size, subcategory_embedding_dim, input_length=1)(input_subcategory)
concept_embedding = Embedding(concept_vocab_size, concept_embedding_dim, input_length=1)(input_concept)

subcategory_flat = Flatten()(subcategory_embedding)
concept_flat = Flatten()(concept_embedding)

concatenated = Concatenate()([input_img, input_text, input_num, input_category, subcategory_flat, concept_flat])
# More complex dense layers
dense1 = Dense(512, activation='relu')(concatenated)
batch_norm1 = BatchNormalization()(dense1)
dropout1 = Dropout(0.5)(batch_norm1)

dense2 = Dense(256, activation='relu')(dropout1)
batch_norm2 = BatchNormalization()(dense2)
dropout2 = Dropout(0.4)(batch_norm2)

dense3 = Dense(128, activation='relu')(dropout2)
batch_norm3 = BatchNormalization()(dense3)
dropout3 = Dropout(0.3)(batch_norm3)

# Adding a residual connection
residual = Dense(128, activation='relu')(dropout1)  # This layer is connected from dropout1
residual_connection = Add()([dropout3, residual])

dense4 = Dense(64, activation='relu')(residual_connection)
batch_norm4 = BatchNormalization()(dense4)
output = Dense(1, activation='linear')(batch_norm4)

model = Model(inputs=[input_img, input_text, input_num, input_category, input_subcategory, input_concept], outputs=output)
model.compile(optimizer='adam', loss='mean_squared_error', metrics=['mae'])
# Out:
# WARNING:tensorflow:From c:\Users\31405.ISBDOMAIN1\AppData\Local\miniconda3\Lib\site-packages\keras\src\backend.py:1398: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# WARNING:tensorflow:From c:\Users\31405.ISBDOMAIN1\AppData\Local\miniconda3\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
X_concept
# Out:
# array([[115],
#        [270],
#        [294],
#        ...,
#        [203],
#        [449],
#        [257]])

# %%
X_train_text, X_test_text, X_train_img, X_test_img, X_train_num, X_test_num, X_train_cat, X_test_cat, X_train_subcat, X_test_subcat, X_train_concept, X_test_concept, y_train, y_test = train_test_split(
    X_text, X_image, X_numerical, X_category, X_subcategory, X_concept, y, test_size=0.2, random_state=42
)

# %%
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=3, min_lr=1e-6, verbose=1)

# %%
class SpearmanRankCorrelation(Callback):
    def __init__(self, train_data, validation_data):
        super(SpearmanRankCorrelation, self).__init__()
        self.train_data = train_data
        self.validation_data = validation_data

    def on_epoch_end(self, epoch, logs=None):
        # Calculate for training data
        X_train = [self.train_data[0][0], self.train_data[0][1], self.train_data[0][2], self.train_data[0][3], self.train_data[0][4], self.train_data[0][5]]
        y_train = self.train_data[1]
        y_train_pred = self.model.predict(X_train)
        train_rho, _ = spearmanr(y_train, y_train_pred[:, 0])
        logs['train_spearman_corr'] = train_rho

        # Calculate for validation data
        X_val = [self.validation_data[0][0], self.validation_data[0][1], self.validation_data[0][2], self.validation_data[0][3], self.validation_data[0][4], self.validation_data[0][5]]
        y_val = self.validation_data[1]
        y_val_pred = self.model.predict(X_val)
        val_rho, _ = spearmanr(y_val, y_val_pred[:, 0])
        logs['val_spearman_corr'] = val_rho

        print(f'Epoch {epoch + 1}: Train Spearman Rank Correlation: {train_rho:.4f}, Val Spearman Rank Correlation: {val_rho:.4f}')



early_stopping = EarlyStopping(monitor='val_mae', patience=11, restore_best_weights=True, verbose=1)
model_checkpoint = ModelCheckpoint('best_model.h5', monitor='val_mae', save_best_only=True, verbose=1)
spearman_callback = SpearmanRankCorrelation(
    train_data=([X_train_img, X_train_text, X_train_num, X_train_cat, X_train_subcat, X_train_concept], y_train),
    validation_data=([X_test_img, X_test_text, X_test_num, X_test_cat, X_test_subcat, X_test_concept], y_test)
)
callbacks = [early_stopping, model_checkpoint, spearman_callback, reduce_lr]

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  subcategory_input (InputLa  [(None, 1)]                  0         []
#  yer)
#
#  concept_input (InputLayer)  [(None, 1)]                  0         []
#
#  embedding (Embedding)       (None, 1, 8)                 632       ['subcategory_input[0][0]']
#
#  embedding_1 (Embedding)     (None, 1, 25)                16725     ['concept_input[0][0]']
#
#  img_input (InputLayer)      [(None, 1000)]               0         []
#
#  text_input (InputLayer)     [(None, 384)]                0         []
#
#  num_input (InputLayer)      [(None, 13)]                 0         []
#
#  category_input (InputLayer  [(None, 11)]                 0         []
#  )
#
#  flatten (Flatten)           (None, 8)                    0         ['embedding[0][0]']
#
#  flatten_1 (Flatten)         (None, 25)                   0         ['embedding_1[0][0]']
#
#  concatenate (Concatenate)   (None, 1441)                 0         ['img_input[0][0]',
#                                                                      'text_input[0][0]',
#                                                                      'num_input[0][0]',
#                                                                      'category_input[0][0]',
#                                                                      'flatten[0][0]',
#                                                                      'flatten_1[0][0]']
#
#  dense (Dense)               (None, 512)                  738304    ['concatenate[0][0]']
#
#  batch_normalization (Batch  (None, 512)                  2048      ['dense[0][0]']
#  Normalization)
#
#  dropout (Dropout)           (None, 512)                  0         ['batch_normalization[0][0]']
#
#  dense_1 (Dense)             (None, 256)                  131328    ['dropout[0][0]']
#
#  batch_normalization_1 (Bat  (None, 256)                  1024      ['dense_1[0][0]']
#  chNormalization)
#
#  dropout_1 (Dropout)         (None, 256)                  0         ['batch_normalization_1[0][0]'
#                                                                     ]
#
#  dense_2 (Dense)             (None, 128)                  32896     ['dropout_1[0][0]']
#
#  batch_normalization_2 (Bat  (None, 128)                  512       ['dense_2[0][0]']
#  chNormalization)
#
#  dropout_2 (Dropout)         (None, 128)                  0         ['batch_normalization_2[0][0]'
#                                                                     ]
#
#  dense_3 (Dense)             (None, 128)                  65664     ['dropout[0][0]']
#
#  add (Add)                   (None, 128)                  0         ['dropout_2[0][0]',
#                                                                      'dense_3[0][0]']
#
#  dense_4 (Dense)             (None, 64)                   8256      ['add[0][0]']
#
#  batch_normalization_3 (Bat  (None, 64)                   256       ['dense_4[0][0]']
#  chNormalization)
#
#  dense_5 (Dense)             (None, 1)                    65        ['batch_normalization_3[0][0]'
#                                                                     ]
#
# ==================================================================================================
# Total params: 997710 (3.81 MB)
# Trainable params: 995790 (3.80 MB)
# Non-trainable params: 1920 (7.50 KB)
# __________________________________________________________________________________________________

# %%
history1= model.fit([X_train_img, X_train_text, X_train_num, X_train_cat, X_train_subcat, X_train_concept], y_train, 
          validation_data=([X_test_img, X_test_text, X_test_num, X_test_cat, X_test_subcat, X_test_concept], y_test),
          epochs=100,  # Adjust as needed
          batch_size=512,
          callbacks=callbacks)
# Out:
# Epoch 1/100
# WARNING:tensorflow:From c:\Users\31405.ISBDOMAIN1\AppData\Local\miniconda3\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From c:\Users\31405.ISBDOMAIN1\AppData\Local\miniconda3\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 392/393 [============================>.] - ETA: 0s - loss: 16.3583 - mae: 3.1494
# Epoch 1: val_mae improved from inf to 10.86634, saving model to best_model.h5
# c:\Users\31405.ISBDOMAIN1\AppData\Local\miniconda3\Lib\site-packages\keras\src\engine\training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 6283/6283 [==============================] - 13s 2ms/step
# 1571/1571 [==============================] - 3s 2ms/step
# Epoch 1: Train Spearman Rank Correlation: 0.4733, Val Spearman Rank Correlation: 0.4726
# 393/393 [==============================] - 32s 73ms/step - loss: 16.3377 - mae: 3.1467 - val_loss: 122.7905 - val_mae: 10.8663 - train_spearman_corr: 0.4733 - val_spearman_corr: 0.4726 - lr: 0.0010
# Epoch 2/100
# 391/393 [============================>.] - ETA: 0s - loss: 4.0356 - mae: 1.5474
# Epoch 2: val_mae improved from 10.86634 to 10.28665, saving model to best_model.h5
# 6283/6283 [==============================] - 12s 2ms/step
# 1571/1571 [==============================] - 3s 2ms/step
# Epoch 2: Train Spearman Rank Correlation: 0.5438, Val Spearman Rank Correlation: 0.5388
# 393/393 [==============================] - 27s 69ms/step - loss: 4.0366 - mae: 1.5476 - val_loss: 110.0184 - val_mae: 10.2867 - train_spearman_corr: 0.5438 - val_spearman_corr: 0.5388 - lr: 0.0010
# Epoch 3/100
# 392/393 [============================>.] - ETA: 0s - loss: 3.7455 - mae: 1.4864
# Epoch 3: val_mae improved from 10.28665 to 6.10082, saving model to best_model.h5
# 6283/6283 [==============================] - 12s 2ms/step
# 1571/1571 [==============================] - 3s 2ms/step
# Epoch 3: Train Spearman Rank Correlation: 0.5978, Val Spearman Rank Correlation: 0.5920
# 393/393 [==============================] - 27s 69ms/step - loss: 3.7453 - mae: 1.4864 - val_loss: 41.1561 - val_mae: 6.1008 - train_spearman_corr: 0.5978 - val_spearman_corr: 0.5920 - lr: 0.0010
# Epoch 4/100
# 391/393 [============================>.] - ETA: 0s - loss: 3.6074 - mae: 1.4573
# Epoch 4: val_mae improved from 6.10082 to 2.52722, saving model to best_model.h5
# 6283/6283 [==============================] - 13s 2ms/step
# 1571/1571 [==============================] - 3s 2ms/step
# Epoch 4: Train Spearman Rank Correlation: 0.5816, Val Spearman Rank Correlation: 0.5773
# 393/393 [==============================] - 27s 70ms/step - loss: 3.6075 - mae: 1.4574 - val_loss: 9.6131 - val_mae: 2.5272 - train_spearman_corr: 0.5816 - val_spearman_corr: 0.5773 - lr: 0.0010
# Epoch 5/100
# 390/393 [============================>.] - ETA: 0s - loss: 3.4931 - mae: 1.4328
# Epoch 5: val_mae did not improve from 2.52722
# 6283/6283 [==============================] - 13s 2ms/step
# 1571/1571 [==============================] - 3s 2ms/step
# Epoch 5: Train Spearman Rank Correlation: 0.5702, Val Spearman Rank Correlation: 0.5650
# 393/393 [==============================] - 27s 70ms/step - loss: 3.4928 - mae: 1.4329 - val_loss: 11.8955 - val_mae: 2.8951 - train_spearman_corr: 0.5702 - val_spearman_corr: 0.5650 - lr: 0.0010
# Epoch 6/100
# 390/393 [============================>.] - ETA: 0s - loss: 3.4035 - mae: 1.4121
# Epoch 6: val_mae did not improve from 2.52722
# 6283/6283 [==============================] - 12s 2ms/step
# 1571/1571 [==============================] - 3s 2ms/step
# Epoch 6: Train Spearman Rank Correlation: 0.5741, Val Spearman Rank Correlation: 0.5693
# 393/393 [==============================] - 27s 69ms/step - loss: 3.4031 - mae: 1.4121 - val_loss: 32.3488 - val_mae: 5.3236 - train_spearman_corr: 0.5741 - val_spearman_corr: 0.5693 - lr: 0.0010
# Epoch 7/100
# 391/393 [============================>.] - ETA: 0s - loss: 3.3354 - mae: 1.3951
# Epoch 7: val_mae did not improve from 2.52722
# 6283/6283 [==============================] - 13s 2ms/step
# 1571/1571 [==============================] - 3s 2ms/step
# Epoch 7: Train Spearman Rank Correlation: 0.6042, Val Spearman Rank Correlation: 0.5968
#
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 393/393 [==============================] - 28s 71ms/step - loss: 3.3349 - mae: 1.3949 - val_loss: 22.1936 - val_mae: 4.2775 - train_spearman_corr: 0.6042 - val_spearman_corr: 0.5968 - lr: 0.0010
# Epoch 8/100
# 391/393 [============================>.] - ETA: 0s - loss: 3.1459 - mae: 1.3498
# Epoch 8: val_mae improved from 2.52722 to 1.52226, saving model to best_model.h5
# 6283/6283 [==============================] - 12s 2ms/step
# 1571/1571 [==============================] - 3s 2ms/step
# Epoch 8: Train Spearman Rank Correlation: 0.6835, Val Spearman Rank Correlation: 0.6728
# 393/393 [==============================] - 27s 69ms/step - loss: 3.1451 - mae: 1.3495 - val_loss: 4.0769 - val_mae: 1.5223 - train_spearman_corr: 0.6835 - val_spearman_corr: 0.6728 - lr: 2.0000e-04
# Epoch 9/100
# 393/393 [==============================] - ETA: 0s - loss: 3.0827 - mae: 1.3342
# Epoch 9: val_mae improved from 1.52226 to 1.41899, saving model to best_model.h5
# 6283/6283 [==============================] - 12s 2ms/step
# 1571/1571 [==============================] - 3s 2ms/step
# Epoch 9: Train Spearman Rank Correlation: 0.6784, Val Spearman Rank Correlation: 0.6685
# 393/393 [==============================] - 27s 69ms/step - loss: 3.0827 - mae: 1.3342 - val_loss: 3.3630 - val_mae: 1.4190 - train_spearman_corr: 0.6784 - val_spearman_corr: 0.6685 - lr: 2.0000e-04
# Epoch 10/100
# 390/393 [============================>.] - ETA: 0s - loss: 3.0464 - mae: 1.3242
# Epoch 10: val_mae improved from 1.41899 to 1.35411, saving model to best_model.h5
# 6283/6283 [==============================] - 12s 2ms/step
# 1571/1571 [==============================] - 3s 2ms/step
# Epoch 10: Train Spearman Rank Correlation: 0.7079, Val Spearman Rank Correlation: 0.6938
# 393/393 [==============================] - 27s 68ms/step - loss: 3.0453 - mae: 1.3240 - val_loss: 3.2273 - val_mae: 1.3541 - train_spearman_corr: 0.7079 - val_spearman_corr: 0.6938 - lr: 2.0000e-04
# Epoch 11/100
# 390/393 [============================>.] - ETA: 0s - loss: 3.0091 - mae: 1.3149
# Epoch 11: val_mae did not improve from 1.35411
# 6283/6283 [==============================] - 14s 2ms/step
# 1571/1571 [==============================] - 3s 2ms/step
# Epoch 11: Train Spearman Rank Correlation: 0.7011, Val Spearman Rank Correlation: 0.6900
# 393/393 [==============================] - 30s 76ms/step - loss: 3.0108 - mae: 1.3152 - val_loss: 3.8835 - val_mae: 1.5762 - train_spearman_corr: 0.7011 - val_spearman_corr: 0.6900 - lr: 2.0000e-04
# Epoch 12/100
# 391/393 [============================>.] - ETA: 0s - loss: 2.9784 - mae: 1.3067
# Epoch 12: val_mae improved from 1.35411 to 1.32130, saving model to best_model.h5
# 6283/6283 [==============================] - 13s 2ms/step
# 1571/1571 [==============================] - 3s 2ms/step
# Epoch 12: Train Spearman Rank Correlation: 0.7133, Val Spearman Rank Correlation: 0.6990
# 393/393 [==============================] - 27s 69ms/step - loss: 2.9792 - mae: 1.3069 - val_loss: 3.0509 - val_mae: 1.3213 - train_spearman_corr: 0.7133 - val_spearman_corr: 0.6990 - lr: 2.0000e-04
# Epoch 13/100
# 393/393 [==============================] - ETA: 0s - loss: 2.9541 - mae: 1.3008
# Epoch 13: val_mae did not improve from 1.32130
# 6283/6283 [==============================] - 12s 2ms/step
# 1571/1571 [==============================] - 3s 2ms/step
# Epoch 13: Train Spearman Rank Correlation: 0.6934, Val Spearman Rank Correlation: 0.6805
# 393/393 [==============================] - 27s 69ms/step - loss: 2.9541 - mae: 1.3008 - val_loss: 4.2999 - val_mae: 1.6596 - train_spearman_corr: 0.6934 - val_spearman_corr: 0.6805 - lr: 2.0000e-04
# Epoch 14/100
# 391/393 [============================>.] - ETA: 0s - loss: 2.9226 - mae: 1.2929
# Epoch 14: val_mae did not improve from 1.32130
# 6283/6283 [==============================] - 13s 2ms/step
# 1571/1571 [==============================] - 3s 2ms/step
# Epoch 14: Train Spearman Rank Correlation: 0.6972, Val Spearman Rank Correlation: 0.6842
# 393/393 [==============================] - 27s 69ms/step - loss: 2.9220 - mae: 1.2928 - val_loss: 3.6972 - val_mae: 1.5182 - train_spearman_corr: 0.6972 - val_spearman_corr: 0.6842 - lr: 2.0000e-04
# Epoch 15/100
# 392/393 [============================>.] - ETA: 0s - loss: 2.8961 - mae: 1.2850
# Epoch 15: val_mae did not improve from 1.32130
# 6283/6283 [==============================] - 12s 2ms/step
# 1571/1571 [==============================] - 3s 2ms/step
# Epoch 15: Train Spearman Rank Correlation: 0.7031, Val Spearman Rank Correlation: 0.6873
#
# Epoch 15: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# 393/393 [==============================] - 27s 68ms/step - loss: 2.8960 - mae: 1.2850 - val_loss: 3.7681 - val_mae: 1.4631 - train_spearman_corr: 0.7031 - val_spearman_corr: 0.6873 - lr: 2.0000e-04
# Epoch 16/100
# 392/393 [============================>.] - ETA: 0s - loss: 2.8405 - mae: 1.2709
# Epoch 16: val_mae improved from 1.32130 to 1.26793, saving model to best_model.h5
# 6283/6283 [==============================] - 12s 2ms/step
# 1571/1571 [==============================] - 3s 2ms/step
# Epoch 16: Train Spearman Rank Correlation: 0.7314, Val Spearman Rank Correlation: 0.7150
# 393/393 [==============================] - 27s 69ms/step - loss: 2.8399 - mae: 1.2707 - val_loss: 2.8735 - val_mae: 1.2679 - train_spearman_corr: 0.7314 - val_spearman_corr: 0.7150 - lr: 4.0000e-05
# Epoch 17/100
# 391/393 [============================>.] - ETA: 0s - loss: 2.8208 - mae: 1.2658
# Epoch 17: val_mae did not improve from 1.26793
# 6283/6283 [==============================] - 12s 2ms/step
# 1571/1571 [==============================] - 3s 2ms/step
# Epoch 17: Train Spearman Rank Correlation: 0.7258, Val Spearman Rank Correlation: 0.7102
# 393/393 [==============================] - 27s 68ms/step - loss: 2.8217 - mae: 1.2661 - val_loss: 3.3616 - val_mae: 1.4320 - train_spearman_corr: 0.7258 - val_spearman_corr: 0.7102 - lr: 4.0000e-05
# Epoch 18/100
# 390/393 [============================>.] - ETA: 0s - loss: 2.8111 - mae: 1.2630
# Epoch 18: val_mae improved from 1.26793 to 1.26383, saving model to best_model.h5
# 6283/6283 [==============================] - 12s 2ms/step
# 1571/1571 [==============================] - 3s 2ms/step
# Epoch 18: Train Spearman Rank Correlation: 0.7364, Val Spearman Rank Correlation: 0.7195
# 393/393 [==============================] - 27s 68ms/step - loss: 2.8130 - mae: 1.2633 - val_loss: 2.8309 - val_mae: 1.2638 - train_spearman_corr: 0.7364 - val_spearman_corr: 0.7195 - lr: 4.0000e-05
# Epoch 19/100
# 392/393 [============================>.] - ETA: 0s - loss: 2.8082 - mae: 1.2625
# Epoch 19: val_mae did not improve from 1.26383
# 6283/6283 [==============================] - 12s 2ms/step
# 1571/1571 [==============================] - 3s 2ms/step
# Epoch 19: Train Spearman Rank Correlation: 0.7343, Val Spearman Rank Correlation: 0.7174
# 393/393 [==============================] - 27s 68ms/step - loss: 2.8084 - mae: 1.2626 - val_loss: 2.9016 - val_mae: 1.2910 - train_spearman_corr: 0.7343 - val_spearman_corr: 0.7174 - lr: 4.0000e-05
# Epoch 20/100
# 392/393 [============================>.] - ETA: 0s - loss: 2.7920 - mae: 1.2581
# Epoch 20: val_mae improved from 1.26383 to 1.25538, saving model to best_model.h5
# 6283/6283 [==============================] - 13s 2ms/step
# 1571/1571 [==============================] - 4s 2ms/step
# Epoch 20: Train Spearman Rank Correlation: 0.7396, Val Spearman Rank Correlation: 0.7219
# 393/393 [==============================] - 29s 74ms/step - loss: 2.7925 - mae: 1.2582 - val_loss: 2.8048 - val_mae: 1.2554 - train_spearman_corr: 0.7396 - val_spearman_corr: 0.7219 - lr: 4.0000e-05
# Epoch 21/100
# 393/393 [==============================] - ETA: 0s - loss: 2.7917 - mae: 1.2578
# Epoch 21: val_mae did not improve from 1.25538
# 6283/6283 [==============================] - 13s 2ms/step
# 1571/1571 [==============================] - 3s 2ms/step
# Epoch 21: Train Spearman Rank Correlation: 0.7361, Val Spearman Rank Correlation: 0.7184
# 393/393 [==============================] - 27s 69ms/step - loss: 2.7917 - mae: 1.2578 - val_loss: 2.8452 - val_mae: 1.2604 - train_spearman_corr: 0.7361 - val_spearman_corr: 0.7184 - lr: 4.0000e-05
# Epoch 22/100
# 393/393 [==============================] - ETA: 0s - loss: 2.7886 - mae: 1.2556
# Epoch 22: val_mae improved from 1.25538 to 1.25216, saving model to best_model.h5
# 6283/6283 [==============================] - 13s 2ms/step
# 1571/1571 [==============================] - 3s 2ms/step
# Epoch 22: Train Spearman Rank Correlation: 0.7391, Val Spearman Rank Correlation: 0.7207
# 393/393 [==============================] - 28s 70ms/step - loss: 2.7886 - mae: 1.2556 - val_loss: 2.8457 - val_mae: 1.2522 - train_spearman_corr: 0.7391 - val_spearman_corr: 0.7207 - lr: 4.0000e-05
# Epoch 23/100
# 393/393 [==============================] - ETA: 0s - loss: 2.7826 - mae: 1.2543
# Epoch 23: val_mae did not improve from 1.25216
# 6283/6283 [==============================] - 13s 2ms/step
# 1571/1571 [==============================] - 3s 2ms/step
# Epoch 23: Train Spearman Rank Correlation: 0.7271, Val Spearman Rank Correlation: 0.7111
#
# Epoch 23: ReduceLROnPlateau reducing learning rate to 8.000000525498762e-06.
# 393/393 [==============================] - 27s 70ms/step - loss: 2.7826 - mae: 1.2543 - val_loss: 3.4241 - val_mae: 1.4472 - train_spearman_corr: 0.7271 - val_spearman_corr: 0.7111 - lr: 4.0000e-05
# Epoch 24/100
# 391/393 [============================>.] - ETA: 0s - loss: 2.7667 - mae: 1.2509
# Epoch 24: val_mae improved from 1.25216 to 1.23921, saving model to best_model.h5
# 6283/6283 [==============================] - 13s 2ms/step
# 1571/1571 [==============================] - 3s 2ms/step
# Epoch 24: Train Spearman Rank Correlation: 0.7428, Val Spearman Rank Correlation: 0.7242
# 393/393 [==============================] - 28s 71ms/step - loss: 2.7668 - mae: 1.2509 - val_loss: 2.7880 - val_mae: 1.2392 - train_spearman_corr: 0.7428 - val_spearman_corr: 0.7242 - lr: 8.0000e-06
# Epoch 25/100
# 392/393 [============================>.] - ETA: 0s - loss: 2.7656 - mae: 1.2506
# Epoch 25: val_mae did not improve from 1.23921
# 6283/6283 [==============================] - 13s 2ms/step
# 1571/1571 [==============================] - 3s 2ms/step
# Epoch 25: Train Spearman Rank Correlation: 0.7427, Val Spearman Rank Correlation: 0.7243
# 393/393 [==============================] - 28s 70ms/step - loss: 2.7663 - mae: 1.2507 - val_loss: 2.7800 - val_mae: 1.2406 - train_spearman_corr: 0.7427 - val_spearman_corr: 0.7243 - lr: 8.0000e-06
# Epoch 26/100
# 391/393 [============================>.] - ETA: 0s - loss: 2.7656 - mae: 1.2506
# Epoch 26: val_mae did not improve from 1.23921
# 6283/6283 [==============================] - 13s 2ms/step
# 1571/1571 [==============================] - 3s 2ms/step
# Epoch 26: Train Spearman Rank Correlation: 0.7426, Val Spearman Rank Correlation: 0.7243
# 393/393 [==============================] - 27s 70ms/step - loss: 2.7653 - mae: 1.2505 - val_loss: 2.7813 - val_mae: 1.2458 - train_spearman_corr: 0.7426 - val_spearman_corr: 0.7243 - lr: 8.0000e-06
# Epoch 27/100
# 390/393 [============================>.] - ETA: 0s - loss: 2.7570 - mae: 1.2478
# Epoch 27: val_mae did not improve from 1.23921
# 6283/6283 [==============================] - 13s 2ms/step
# 1571/1571 [==============================] - 3s 2ms/step
# Epoch 27: Train Spearman Rank Correlation: 0.7433, Val Spearman Rank Correlation: 0.7247
# 393/393 [==============================] - 28s 70ms/step - loss: 2.7574 - mae: 1.2480 - val_loss: 2.7774 - val_mae: 1.2447 - train_spearman_corr: 0.7433 - val_spearman_corr: 0.7247 - lr: 8.0000e-06
# Epoch 28/100
# 391/393 [============================>.] - ETA: 0s - loss: 2.7561 - mae: 1.2485
# Epoch 28: val_mae improved from 1.23921 to 1.23911, saving model to best_model.h5
# 6283/6283 [==============================] - 13s 2ms/step
# 1571/1571 [==============================] - 3s 2ms/step
# Epoch 28: Train Spearman Rank Correlation: 0.7437, Val Spearman Rank Correlation: 0.7251
# 393/393 [==============================] - 28s 71ms/step - loss: 2.7558 - mae: 1.2484 - val_loss: 2.7723 - val_mae: 1.2391 - train_spearman_corr: 0.7437 - val_spearman_corr: 0.7251 - lr: 8.0000e-06
# Epoch 29/100
# 392/393 [============================>.] - ETA: 0s - loss: 2.7594 - mae: 1.2492
# Epoch 29: val_mae did not improve from 1.23911
# 6283/6283 [==============================] - 13s 2ms/step
# 1571/1571 [==============================] - 3s 2ms/step
# Epoch 29: Train Spearman Rank Correlation: 0.7430, Val Spearman Rank Correlation: 0.7245
# 393/393 [==============================] - 28s 71ms/step - loss: 2.7593 - mae: 1.2492 - val_loss: 2.7788 - val_mae: 1.2461 - train_spearman_corr: 0.7430 - val_spearman_corr: 0.7245 - lr: 8.0000e-06
# Epoch 30/100
# 390/393 [============================>.] - ETA: 0s - loss: 2.7597 - mae: 1.2495
# Epoch 30: val_mae did not improve from 1.23911
# 6283/6283 [==============================] - 13s 2ms/step
# 1571/1571 [==============================] - 4s 3ms/step
# Epoch 30: Train Spearman Rank Correlation: 0.7433, Val Spearman Rank Correlation: 0.7248
# 393/393 [==============================] - 29s 75ms/step - loss: 2.7591 - mae: 1.2492 - val_loss: 2.7891 - val_mae: 1.2523 - train_spearman_corr: 0.7433 - val_spearman_corr: 0.7248 - lr: 8.0000e-06
# Epoch 31/100
# 390/393 [============================>.] - ETA: 0s - loss: 2.7531 - mae: 1.2475
# Epoch 31: val_mae did not improve from 1.23911
# 6283/6283 [==============================] - 13s 2ms/step
# 1571/1571 [==============================] - 3s 2ms/step
# Epoch 31: Train Spearman Rank Correlation: 0.7433, Val Spearman Rank Correlation: 0.7248
#
# Epoch 31: ReduceLROnPlateau reducing learning rate to 1.6000001778593287e-06.
# 393/393 [==============================] - 28s 70ms/step - loss: 2.7525 - mae: 1.2475 - val_loss: 2.7864 - val_mae: 1.2505 - train_spearman_corr: 0.7433 - val_spearman_corr: 0.7248 - lr: 8.0000e-06
# Epoch 32/100
# 391/393 [============================>.] - ETA: 0s - loss: 2.7489 - mae: 1.2464
# Epoch 32: val_mae did not improve from 1.23911
# 6283/6283 [==============================] - 13s 2ms/step
# 1571/1571 [==============================] - 3s 2ms/step
# Epoch 32: Train Spearman Rank Correlation: 0.7440, Val Spearman Rank Correlation: 0.7253
# 393/393 [==============================] - 28s 71ms/step - loss: 2.7487 - mae: 1.2464 - val_loss: 2.7702 - val_mae: 1.2393 - train_spearman_corr: 0.7440 - val_spearman_corr: 0.7253 - lr: 1.6000e-06
# Epoch 33/100
# 392/393 [============================>.] - ETA: 0s - loss: 2.7561 - mae: 1.2479
# Epoch 33: val_mae improved from 1.23911 to 1.23854, saving model to best_model.h5
# 6283/6283 [==============================] - 13s 2ms/step
# 1571/1571 [==============================] - 3s 2ms/step
# Epoch 33: Train Spearman Rank Correlation: 0.7442, Val Spearman Rank Correlation: 0.7255
# 393/393 [==============================] - 28s 70ms/step - loss: 2.7558 - mae: 1.2478 - val_loss: 2.7688 - val_mae: 1.2385 - train_spearman_corr: 0.7442 - val_spearman_corr: 0.7255 - lr: 1.6000e-06
# Epoch 34/100
# 390/393 [============================>.] - ETA: 0s - loss: 2.7496 - mae: 1.2472
# Epoch 34: val_mae did not improve from 1.23854
# 6283/6283 [==============================] - 13s 2ms/step
# 1571/1571 [==============================] - 3s 2ms/step
# Epoch 34: Train Spearman Rank Correlation: 0.7441, Val Spearman Rank Correlation: 0.7254
# 393/393 [==============================] - 27s 70ms/step - loss: 2.7480 - mae: 1.2470 - val_loss: 2.7703 - val_mae: 1.2413 - train_spearman_corr: 0.7441 - val_spearman_corr: 0.7254 - lr: 1.6000e-06
# Epoch 35/100
# 390/393 [============================>.] - ETA: 0s - loss: 2.7512 - mae: 1.2471
# Epoch 35: val_mae did not improve from 1.23854
# 6283/6283 [==============================] - 13s 2ms/step
# 1571/1571 [==============================] - 3s 2ms/step
# Epoch 35: Train Spearman Rank Correlation: 0.7442, Val Spearman Rank Correlation: 0.7255
# 393/393 [==============================] - 27s 69ms/step - loss: 2.7508 - mae: 1.2471 - val_loss: 2.7686 - val_mae: 1.2391 - train_spearman_corr: 0.7442 - val_spearman_corr: 0.7255 - lr: 1.6000e-06
# Epoch 36/100
# 393/393 [==============================] - ETA: 0s - loss: 2.7506 - mae: 1.2462
# Epoch 36: val_mae did not improve from 1.23854
# 6283/6283 [==============================] - 13s 2ms/step
# 1571/1571 [==============================] - 3s 2ms/step
# Epoch 36: Train Spearman Rank Correlation: 0.7442, Val Spearman Rank Correlation: 0.7255
# 393/393 [==============================] - 28s 70ms/step - loss: 2.7506 - mae: 1.2462 - val_loss: 2.7686 - val_mae: 1.2395 - train_spearman_corr: 0.7442 - val_spearman_corr: 0.7255 - lr: 1.6000e-06
# Epoch 37/100
# 390/393 [============================>.] - ETA: 0s - loss: 2.7512 - mae: 1.2470
# Epoch 37: val_mae did not improve from 1.23854
# 6283/6283 [==============================] - 13s 2ms/step
# 1571/1571 [==============================] - 3s 2ms/step
# Epoch 37: Train Spearman Rank Correlation: 0.7442, Val Spearman Rank Correlation: 0.7255
# 393/393 [==============================] - 27s 70ms/step - loss: 2.7518 - mae: 1.2470 - val_loss: 2.7689 - val_mae: 1.2389 - train_spearman_corr: 0.7442 - val_spearman_corr: 0.7255 - lr: 1.6000e-06
# Epoch 38/100
# 392/393 [============================>.] - ETA: 0s - loss: 2.7509 - mae: 1.2466
# Epoch 38: val_mae improved from 1.23854 to 1.23802, saving model to best_model.h5
# 6283/6283 [==============================] - 12s 2ms/step
# 1571/1571 [==============================] - 3s 2ms/step
# Epoch 38: Train Spearman Rank Correlation: 0.7443, Val Spearman Rank Correlation: 0.7255
#
# Epoch 38: ReduceLROnPlateau reducing learning rate to 1e-06.
# 393/393 [==============================] - 27s 69ms/step - loss: 2.7512 - mae: 1.2466 - val_loss: 2.7689 - val_mae: 1.2380 - train_spearman_corr: 0.7443 - val_spearman_corr: 0.7255 - lr: 1.6000e-06
# Epoch 39/100
# 392/393 [============================>.] - ETA: 0s - loss: 2.7508 - mae: 1.2468
# Epoch 39: val_mae did not improve from 1.23802
# 6283/6283 [==============================] - 12s 2ms/step
# 1571/1571 [==============================] - 3s 2ms/step
# Epoch 39: Train Spearman Rank Correlation: 0.7443, Val Spearman Rank Correlation: 0.7256
# 393/393 [==============================] - 27s 68ms/step - loss: 2.7503 - mae: 1.2468 - val_loss: 2.7677 - val_mae: 1.2388 - train_spearman_corr: 0.7443 - val_spearman_corr: 0.7256 - lr: 1.0000e-06
# Epoch 40/100
# 390/393 [============================>.] - ETA: 0s - loss: 2.7483 - mae: 1.2464
# Epoch 40: val_mae improved from 1.23802 to 1.23762, saving model to best_model.h5
# 6283/6283 [==============================] - 15s 2ms/step
# 1571/1571 [==============================] - 3s 2ms/step
# Epoch 40: Train Spearman Rank Correlation: 0.7444, Val Spearman Rank Correlation: 0.7256
# 393/393 [==============================] - 30s 76ms/step - loss: 2.7490 - mae: 1.2466 - val_loss: 2.7678 - val_mae: 1.2376 - train_spearman_corr: 0.7444 - val_spearman_corr: 0.7256 - lr: 1.0000e-06
# Epoch 41/100
# 392/393 [============================>.] - ETA: 0s - loss: 2.7508 - mae: 1.2464
# Epoch 41: val_mae did not improve from 1.23762
# 6283/6283 [==============================] - 13s 2ms/step
# 1571/1571 [==============================] - 3s 2ms/step
# Epoch 41: Train Spearman Rank Correlation: 0.7444, Val Spearman Rank Correlation: 0.7256
# 393/393 [==============================] - 27s 69ms/step - loss: 2.7500 - mae: 1.2463 - val_loss: 2.7678 - val_mae: 1.2386 - train_spearman_corr: 0.7444 - val_spearman_corr: 0.7256 - lr: 1.0000e-06
# Epoch 42/100
# 390/393 [============================>.] - ETA: 0s - loss: 2.7546 - mae: 1.2468
# Epoch 42: val_mae did not improve from 1.23762
# 6283/6283 [==============================] - 13s 2ms/step
# 1571/1571 [==============================] - 3s 2ms/step
# Epoch 42: Train Spearman Rank Correlation: 0.7444, Val Spearman Rank Correlation: 0.7256
# 393/393 [==============================] - 27s 69ms/step - loss: 2.7539 - mae: 1.2468 - val_loss: 2.7678 - val_mae: 1.2387 - train_spearman_corr: 0.7444 - val_spearman_corr: 0.7256 - lr: 1.0000e-06
# Epoch 43/100
# 392/393 [============================>.] - ETA: 0s - loss: 2.7515 - mae: 1.2472
# Epoch 43: val_mae did not improve from 1.23762
# 6283/6283 [==============================] - 13s 2ms/step
# 1571/1571 [==============================] - 3s 2ms/step
# Epoch 43: Train Spearman Rank Correlation: 0.7444, Val Spearman Rank Correlation: 0.7256
# 393/393 [==============================] - 27s 69ms/step - loss: 2.7517 - mae: 1.2473 - val_loss: 2.7679 - val_mae: 1.2392 - train_spearman_corr: 0.7444 - val_spearman_corr: 0.7256 - lr: 1.0000e-06
# Epoch 44/100
# 392/393 [============================>.] - ETA: 0s - loss: 2.7467 - mae: 1.2454
# Epoch 44: val_mae did not improve from 1.23762
# 6283/6283 [==============================] - 13s 2ms/step
# 1571/1571 [==============================] - 3s 2ms/step
# Epoch 44: Train Spearman Rank Correlation: 0.7444, Val Spearman Rank Correlation: 0.7256
# 393/393 [==============================] - 27s 69ms/step - loss: 2.7470 - mae: 1.2454 - val_loss: 2.7674 - val_mae: 1.2385 - train_spearman_corr: 0.7444 - val_spearman_corr: 0.7256 - lr: 1.0000e-06
# Epoch 45/100
# 391/393 [============================>.] - ETA: 0s - loss: 2.7448 - mae: 1.2459
# Epoch 45: val_mae improved from 1.23762 to 1.23759, saving model to best_model.h5
# 6283/6283 [==============================] - 13s 2ms/step
# 1571/1571 [==============================] - 3s 2ms/step
# Epoch 45: Train Spearman Rank Correlation: 0.7445, Val Spearman Rank Correlation: 0.7257
# 393/393 [==============================] - 27s 70ms/step - loss: 2.7450 - mae: 1.2459 - val_loss: 2.7673 - val_mae: 1.2376 - train_spearman_corr: 0.7445 - val_spearman_corr: 0.7257 - lr: 1.0000e-06
# Epoch 46/100
# 392/393 [============================>.] - ETA: 0s - loss: 2.7469 - mae: 1.2449
# Epoch 46: val_mae did not improve from 1.23759
# 6283/6283 [==============================] - 12s 2ms/step
# 1571/1571 [==============================] - 3s 2ms/step
# Epoch 46: Train Spearman Rank Correlation: 0.7445, Val Spearman Rank Correlation: 0.7257
# 393/393 [==============================] - 27s 68ms/step - loss: 2.7468 - mae: 1.2450 - val_loss: 2.7668 - val_mae: 1.2392 - train_spearman_corr: 0.7445 - val_spearman_corr: 0.7257 - lr: 1.0000e-06
# Epoch 47/100
# 393/393 [==============================] - ETA: 0s - loss: 2.7453 - mae: 1.2451
# Epoch 47: val_mae did not improve from 1.23759
# 6283/6283 [==============================] - 13s 2ms/step
# 1571/1571 [==============================] - 3s 2ms/step
# Epoch 47: Train Spearman Rank Correlation: 0.7446, Val Spearman Rank Correlation: 0.7257
# 393/393 [==============================] - 27s 69ms/step - loss: 2.7453 - mae: 1.2451 - val_loss: 2.7667 - val_mae: 1.2380 - train_spearman_corr: 0.7446 - val_spearman_corr: 0.7257 - lr: 1.0000e-06
# Epoch 48/100
# 390/393 [============================>.] - ETA: 0s - loss: 2.7467 - mae: 1.2455
# Epoch 48: val_mae did not improve from 1.23759
# 6283/6283 [==============================] - 12s 2ms/step
# 1571/1571 [==============================] - 3s 2ms/step
# Epoch 48: Train Spearman Rank Correlation: 0.7445, Val Spearman Rank Correlation: 0.7257
# 393/393 [==============================] - 27s 69ms/step - loss: 2.7468 - mae: 1.2455 - val_loss: 2.7667 - val_mae: 1.2383 - train_spearman_corr: 0.7445 - val_spearman_corr: 0.7257 - lr: 1.0000e-06
# Epoch 49/100
# 392/393 [============================>.] - ETA: 0s - loss: 2.7504 - mae: 1.2467
# Epoch 49: val_mae did not improve from 1.23759
# 6283/6283 [==============================] - 13s 2ms/step
# 1571/1571 [==============================] - 4s 2ms/step
# Epoch 49: Train Spearman Rank Correlation: 0.7446, Val Spearman Rank Correlation: 0.7257
# 393/393 [==============================] - 30s 76ms/step - loss: 2.7496 - mae: 1.2465 - val_loss: 2.7667 - val_mae: 1.2376 - train_spearman_corr: 0.7446 - val_spearman_corr: 0.7257 - lr: 1.0000e-06
# Epoch 50/100
# 392/393 [============================>.] - ETA: 0s - loss: 2.7444 - mae: 1.2456
# Epoch 50: val_mae did not improve from 1.23759
# 6283/6283 [==============================] - 13s 2ms/step
# 1571/1571 [==============================] - 3s 2ms/step
# Epoch 50: Train Spearman Rank Correlation: 0.7446, Val Spearman Rank Correlation: 0.7258
# 393/393 [==============================] - 28s 70ms/step - loss: 2.7446 - mae: 1.2456 - val_loss: 2.7664 - val_mae: 1.2377 - train_spearman_corr: 0.7446 - val_spearman_corr: 0.7258 - lr: 1.0000e-06
# Epoch 51/100
# 391/393 [============================>.] - ETA: 0s - loss: 2.7458 - mae: 1.2462
# Epoch 51: val_mae did not improve from 1.23759
# 6283/6283 [==============================] - 13s 2ms/step
# 1571/1571 [==============================] - 3s 2ms/step
# Epoch 51: Train Spearman Rank Correlation: 0.7446, Val Spearman Rank Correlation: 0.7258
# 393/393 [==============================] - 28s 71ms/step - loss: 2.7457 - mae: 1.2463 - val_loss: 2.7663 - val_mae: 1.2383 - train_spearman_corr: 0.7446 - val_spearman_corr: 0.7258 - lr: 1.0000e-06
# Epoch 52/100
# 390/393 [============================>.] - ETA: 0s - loss: 2.7516 - mae: 1.2471
# Epoch 52: val_mae did not improve from 1.23759
# 6283/6283 [==============================] - 13s 2ms/step
# 1571/1571 [==============================] - 3s 2ms/step
# Epoch 52: Train Spearman Rank Correlation: 0.7446, Val Spearman Rank Correlation: 0.7257
# 393/393 [==============================] - 28s 71ms/step - loss: 2.7504 - mae: 1.2469 - val_loss: 2.7664 - val_mae: 1.2387 - train_spearman_corr: 0.7446 - val_spearman_corr: 0.7257 - lr: 1.0000e-06
# Epoch 53/100
# 392/393 [============================>.] - ETA: 0s - loss: 2.7533 - mae: 1.2471
# Epoch 53: val_mae did not improve from 1.23759
# 6283/6283 [==============================] - 13s 2ms/step
# 1571/1571 [==============================] - 3s 2ms/step
# Epoch 53: Train Spearman Rank Correlation: 0.7447, Val Spearman Rank Correlation: 0.7258
# 393/393 [==============================] - 28s 72ms/step - loss: 2.7533 - mae: 1.2471 - val_loss: 2.7660 - val_mae: 1.2382 - train_spearman_corr: 0.7447 - val_spearman_corr: 0.7258 - lr: 1.0000e-06
# Epoch 54/100
# 390/393 [============================>.] - ETA: 0s - loss: 2.7493 - mae: 1.2471
# Epoch 54: val_mae did not improve from 1.23759
# 6283/6283 [==============================] - 13s 2ms/step
# 1571/1571 [==============================] - 3s 2ms/step
# Epoch 54: Train Spearman Rank Correlation: 0.7447, Val Spearman Rank Correlation: 0.7258
# 393/393 [==============================] - 28s 70ms/step - loss: 2.7489 - mae: 1.2470 - val_loss: 2.7656 - val_mae: 1.2386 - train_spearman_corr: 0.7447 - val_spearman_corr: 0.7258 - lr: 1.0000e-06
# Epoch 55/100
# 390/393 [============================>.] - ETA: 0s - loss: 2.7411 - mae: 1.2453
# Epoch 55: val_mae improved from 1.23759 to 1.23750, saving model to best_model.h5
# 6283/6283 [==============================] - 13s 2ms/step
# 1571/1571 [==============================] - 3s 2ms/step
# Epoch 55: Train Spearman Rank Correlation: 0.7447, Val Spearman Rank Correlation: 0.7259
# 393/393 [==============================] - 28s 71ms/step - loss: 2.7411 - mae: 1.2454 - val_loss: 2.7655 - val_mae: 1.2375 - train_spearman_corr: 0.7447 - val_spearman_corr: 0.7259 - lr: 1.0000e-06
# Epoch 56/100
# 391/393 [============================>.] - ETA: 0s - loss: 2.7488 - mae: 1.2464
# Epoch 56: val_mae did not improve from 1.23750
# 6283/6283 [==============================] - 13s 2ms/step
# 1571/1571 [==============================] - 3s 2ms/step
# Epoch 56: Train Spearman Rank Correlation: 0.7447, Val Spearman Rank Correlation: 0.7259
# 393/393 [==============================] - 28s 71ms/step - loss: 2.7479 - mae: 1.2461 - val_loss: 2.7656 - val_mae: 1.2380 - train_spearman_corr: 0.7447 - val_spearman_corr: 0.7259 - lr: 1.0000e-06
# Epoch 57/100
# 390/393 [============================>.] - ETA: 0s - loss: 2.7458 - mae: 1.2461
# Epoch 57: val_mae improved from 1.23750 to 1.23725, saving model to best_model.h5
# 6283/6283 [==============================] - 13s 2ms/step
# 1571/1571 [==============================] - 3s 2ms/step
# Epoch 57: Train Spearman Rank Correlation: 0.7447, Val Spearman Rank Correlation: 0.7258
# 393/393 [==============================] - 27s 70ms/step - loss: 2.7462 - mae: 1.2461 - val_loss: 2.7656 - val_mae: 1.2373 - train_spearman_corr: 0.7447 - val_spearman_corr: 0.7258 - lr: 1.0000e-06
# Epoch 58/100
# 392/393 [============================>.] - ETA: 0s - loss: 2.7449 - mae: 1.2452
# Epoch 58: val_mae did not improve from 1.23725
# 6283/6283 [==============================] - 13s 2ms/step
# 1571/1571 [==============================] - 3s 2ms/step
# Epoch 58: Train Spearman Rank Correlation: 0.7448, Val Spearman Rank Correlation: 0.7259
# 393/393 [==============================] - 27s 70ms/step - loss: 2.7446 - mae: 1.2451 - val_loss: 2.7653 - val_mae: 1.2373 - train_spearman_corr: 0.7448 - val_spearman_corr: 0.7259 - lr: 1.0000e-06
# Epoch 59/100
# 390/393 [============================>.] - ETA: 0s - loss: 2.7498 - mae: 1.2466
# Epoch 59: val_mae did not improve from 1.23725
# 6283/6283 [==============================] - 12s 2ms/step
# 1571/1571 [==============================] - 4s 2ms/step
# Epoch 59: Train Spearman Rank Correlation: 0.7447, Val Spearman Rank Correlation: 0.7259
# 393/393 [==============================] - 29s 74ms/step - loss: 2.7492 - mae: 1.2466 - val_loss: 2.7656 - val_mae: 1.2373 - train_spearman_corr: 0.7447 - val_spearman_corr: 0.7259 - lr: 1.0000e-06
# Epoch 60/100
# 391/393 [============================>.] - ETA: 0s - loss: 2.7471 - mae: 1.2464
# Epoch 60: val_mae did not improve from 1.23725
# 6283/6283 [==============================] - 13s 2ms/step
# 1571/1571 [==============================] - 3s 2ms/step
# Epoch 60: Train Spearman Rank Correlation: 0.7448, Val Spearman Rank Correlation: 0.7259
# 393/393 [==============================] - 28s 71ms/step - loss: 2.7473 - mae: 1.2464 - val_loss: 2.7648 - val_mae: 1.2377 - train_spearman_corr: 0.7448 - val_spearman_corr: 0.7259 - lr: 1.0000e-06
# Epoch 61/100
# 390/393 [============================>.] - ETA: 0s - loss: 2.7464 - mae: 1.2459
# Epoch 61: val_mae did not improve from 1.23725
# 6283/6283 [==============================] - 13s 2ms/step
# 1571/1571 [==============================] - 3s 2ms/step
# Epoch 61: Train Spearman Rank Correlation: 0.7448, Val Spearman Rank Correlation: 0.7259
# 393/393 [==============================] - 27s 70ms/step - loss: 2.7462 - mae: 1.2457 - val_loss: 2.7650 - val_mae: 1.2381 - train_spearman_corr: 0.7448 - val_spearman_corr: 0.7259 - lr: 1.0000e-06
# Epoch 62/100
# 390/393 [============================>.] - ETA: 0s - loss: 2.7471 - mae: 1.2458
# Epoch 62: val_mae improved from 1.23725 to 1.23722, saving model to best_model.h5
# 6283/6283 [==============================] - 13s 2ms/step
# 1571/1571 [==============================] - 3s 2ms/step
# Epoch 62: Train Spearman Rank Correlation: 0.7448, Val Spearman Rank Correlation: 0.7259
# 393/393 [==============================] - 28s 70ms/step - loss: 2.7482 - mae: 1.2461 - val_loss: 2.7648 - val_mae: 1.2372 - train_spearman_corr: 0.7448 - val_spearman_corr: 0.7259 - lr: 1.0000e-06
# Epoch 63/100
# 390/393 [============================>.] - ETA: 0s - loss: 2.7485 - mae: 1.2458
# Epoch 63: val_mae did not improve from 1.23722
# 6283/6283 [==============================] - 13s 2ms/step
# 1571/1571 [==============================] - 3s 2ms/step
# Epoch 63: Train Spearman Rank Correlation: 0.7449, Val Spearman Rank Correlation: 0.7260
# 393/393 [==============================] - 27s 69ms/step - loss: 2.7484 - mae: 1.2457 - val_loss: 2.7644 - val_mae: 1.2373 - train_spearman_corr: 0.7449 - val_spearman_corr: 0.7260 - lr: 1.0000e-06
# Epoch 64/100
# 392/393 [============================>.] - ETA: 0s - loss: 2.7452 - mae: 1.2456
# Epoch 64: val_mae improved from 1.23722 to 1.23666, saving model to best_model.h5
# 6283/6283 [==============================] - 13s 2ms/step
# 1571/1571 [==============================] - 3s 2ms/step
# Epoch 64: Train Spearman Rank Correlation: 0.7449, Val Spearman Rank Correlation: 0.7260
# 393/393 [==============================] - 27s 70ms/step - loss: 2.7458 - mae: 1.2456 - val_loss: 2.7645 - val_mae: 1.2367 - train_spearman_corr: 0.7449 - val_spearman_corr: 0.7260 - lr: 1.0000e-06
# Epoch 65/100
# 390/393 [============================>.] - ETA: 0s - loss: 2.7484 - mae: 1.2464
# Epoch 65: val_mae did not improve from 1.23666
# 6283/6283 [==============================] - 13s 2ms/step
# 1571/1571 [==============================] - 3s 2ms/step
# Epoch 65: Train Spearman Rank Correlation: 0.7449, Val Spearman Rank Correlation: 0.7260
# 393/393 [==============================] - 27s 70ms/step - loss: 2.7481 - mae: 1.2462 - val_loss: 2.7645 - val_mae: 1.2369 - train_spearman_corr: 0.7449 - val_spearman_corr: 0.7260 - lr: 1.0000e-06
# Epoch 66/100
# 392/393 [============================>.] - ETA: 0s - loss: 2.7461 - mae: 1.2460
# Epoch 66: val_mae did not improve from 1.23666
# 6283/6283 [==============================] - 12s 2ms/step
# 1571/1571 [==============================] - 3s 2ms/step
# Epoch 66: Train Spearman Rank Correlation: 0.7449, Val Spearman Rank Correlation: 0.7260
# 393/393 [==============================] - 27s 68ms/step - loss: 2.7457 - mae: 1.2459 - val_loss: 2.7643 - val_mae: 1.2373 - train_spearman_corr: 0.7449 - val_spearman_corr: 0.7260 - lr: 1.0000e-06
# Epoch 67/100
# 393/393 [==============================] - ETA: 0s - loss: 2.7460 - mae: 1.2456
# Epoch 67: val_mae did not improve from 1.23666
# 6283/6283 [==============================] - 13s 2ms/step
# 1571/1571 [==============================] - 3s 2ms/step
# Epoch 67: Train Spearman Rank Correlation: 0.7449, Val Spearman Rank Correlation: 0.7260
# 393/393 [==============================] - 27s 69ms/step - loss: 2.7460 - mae: 1.2456 - val_loss: 2.7643 - val_mae: 1.2388 - train_spearman_corr: 0.7449 - val_spearman_corr: 0.7260 - lr: 1.0000e-06
# Epoch 68/100
# 390/393 [============================>.] - ETA: 0s - loss: 2.7510 - mae: 1.2473
# Epoch 68: val_mae did not improve from 1.23666
# 6283/6283 [==============================] - 12s 2ms/step
# 1571/1571 [==============================] - 3s 2ms/step
# Epoch 68: Train Spearman Rank Correlation: 0.7450, Val Spearman Rank Correlation: 0.7261
# 393/393 [==============================] - 27s 68ms/step - loss: 2.7507 - mae: 1.2472 - val_loss: 2.7637 - val_mae: 1.2372 - train_spearman_corr: 0.7450 - val_spearman_corr: 0.7261 - lr: 1.0000e-06
# Epoch 69/100
# 392/393 [============================>.] - ETA: 0s - loss: 2.7480 - mae: 1.2464
# Epoch 69: val_mae did not improve from 1.23666
# 6283/6283 [==============================] - 14s 2ms/step
# 1571/1571 [==============================] - 3s 2ms/step
# Epoch 69: Train Spearman Rank Correlation: 0.7449, Val Spearman Rank Correlation: 0.7260
# 393/393 [==============================] - 29s 73ms/step - loss: 2.7482 - mae: 1.2465 - val_loss: 2.7639 - val_mae: 1.2378 - train_spearman_corr: 0.7449 - val_spearman_corr: 0.7260 - lr: 1.0000e-06
# Epoch 70/100
# 392/393 [============================>.] - ETA: 0s - loss: 2.7460 - mae: 1.2457
# Epoch 70: val_mae did not improve from 1.23666
# 6283/6283 [==============================] - 12s 2ms/step
# 1571/1571 [==============================] - 3s 2ms/step
# Epoch 70: Train Spearman Rank Correlation: 0.7449, Val Spearman Rank Correlation: 0.7261
# 393/393 [==============================] - 26s 67ms/step - loss: 2.7465 - mae: 1.2459 - val_loss: 2.7641 - val_mae: 1.2373 - train_spearman_corr: 0.7449 - val_spearman_corr: 0.7261 - lr: 1.0000e-06
# Epoch 71/100
# 393/393 [==============================] - ETA: 0s - loss: 2.7477 - mae: 1.2465
# Epoch 71: val_mae did not improve from 1.23666
# 6283/6283 [==============================] - 13s 2ms/step
# 1571/1571 [==============================] - 3s 2ms/step
# Epoch 71: Train Spearman Rank Correlation: 0.7450, Val Spearman Rank Correlation: 0.7261
# 393/393 [==============================] - 27s 68ms/step - loss: 2.7477 - mae: 1.2465 - val_loss: 2.7633 - val_mae: 1.2373 - train_spearman_corr: 0.7450 - val_spearman_corr: 0.7261 - lr: 1.0000e-06
# Epoch 72/100
# 390/393 [============================>.] - ETA: 0s - loss: 2.7426 - mae: 1.2443
# Epoch 72: val_mae improved from 1.23666 to 1.23660, saving model to best_model.h5
# 6283/6283 [==============================] - 12s 2ms/step
# 1571/1571 [==============================] - 3s 2ms/step
# Epoch 72: Train Spearman Rank Correlation: 0.7450, Val Spearman Rank Correlation: 0.7261
# 393/393 [==============================] - 26s 68ms/step - loss: 2.7437 - mae: 1.2445 - val_loss: 2.7635 - val_mae: 1.2366 - train_spearman_corr: 0.7450 - val_spearman_corr: 0.7261 - lr: 1.0000e-06
# Epoch 73/100
# 391/393 [============================>.] - ETA: 0s - loss: 2.7439 - mae: 1.2446
# Epoch 73: val_mae did not improve from 1.23660
# 6283/6283 [==============================] - 13s 2ms/step
# 1571/1571 [==============================] - 3s 2ms/step
# Epoch 73: Train Spearman Rank Correlation: 0.7450, Val Spearman Rank Correlation: 0.7261
# 393/393 [==============================] - 27s 69ms/step - loss: 2.7438 - mae: 1.2446 - val_loss: 2.7634 - val_mae: 1.2370 - train_spearman_corr: 0.7450 - val_spearman_corr: 0.7261 - lr: 1.0000e-06
# Epoch 74/100
# 391/393 [============================>.] - ETA: 0s - loss: 2.7388 - mae: 1.2444
# Epoch 74: val_mae improved from 1.23660 to 1.23643, saving model to best_model.h5
# 6283/6283 [==============================] - 12s 2ms/step
# 1571/1571 [==============================] - 3s 2ms/step
# Epoch 74: Train Spearman Rank Correlation: 0.7451, Val Spearman Rank Correlation: 0.7262
# 393/393 [==============================] - 27s 69ms/step - loss: 2.7395 - mae: 1.2445 - val_loss: 2.7631 - val_mae: 1.2364 - train_spearman_corr: 0.7451 - val_spearman_corr: 0.7262 - lr: 1.0000e-06
# Epoch 75/100
# 392/393 [============================>.] - ETA: 0s - loss: 2.7424 - mae: 1.2448
# Epoch 75: val_mae did not improve from 1.23643
# 6283/6283 [==============================] - 12s 2ms/step
# 1571/1571 [==============================] - 3s 2ms/step
# Epoch 75: Train Spearman Rank Correlation: 0.7451, Val Spearman Rank Correlation: 0.7261
# 393/393 [==============================] - 27s 69ms/step - loss: 2.7426 - mae: 1.2449 - val_loss: 2.7629 - val_mae: 1.2371 - train_spearman_corr: 0.7451 - val_spearman_corr: 0.7261 - lr: 1.0000e-06
# Epoch 76/100
# 393/393 [==============================] - ETA: 0s - loss: 2.7416 - mae: 1.2451
# Epoch 76: val_mae did not improve from 1.23643
# 6283/6283 [==============================] - 13s 2ms/step
# 1571/1571 [==============================] - 3s 2ms/step
# Epoch 76: Train Spearman Rank Correlation: 0.7451, Val Spearman Rank Correlation: 0.7261
# 393/393 [==============================] - 27s 69ms/step - loss: 2.7416 - mae: 1.2451 - val_loss: 2.7629 - val_mae: 1.2376 - train_spearman_corr: 0.7451 - val_spearman_corr: 0.7261 - lr: 1.0000e-06
# Epoch 77/100
# 391/393 [============================>.] - ETA: 0s - loss: 2.7435 - mae: 1.2446
# Epoch 77: val_mae improved from 1.23643 to 1.23633, saving model to best_model.h5
# 6283/6283 [==============================] - 12s 2ms/step
# 1571/1571 [==============================] - 3s 2ms/step
# Epoch 77: Train Spearman Rank Correlation: 0.7452, Val Spearman Rank Correlation: 0.7262
# 393/393 [==============================] - 27s 69ms/step - loss: 2.7431 - mae: 1.2444 - val_loss: 2.7626 - val_mae: 1.2363 - train_spearman_corr: 0.7452 - val_spearman_corr: 0.7262 - lr: 1.0000e-06
# Epoch 78/100
# 393/393 [==============================] - ETA: 0s - loss: 2.7471 - mae: 1.2455
# Epoch 78: val_mae did not improve from 1.23633
# 6283/6283 [==============================] - 12s 2ms/step
# 1571/1571 [==============================] - 4s 2ms/step
# Epoch 78: Train Spearman Rank Correlation: 0.7451, Val Spearman Rank Correlation: 0.7262
# 393/393 [==============================] - 29s 74ms/step - loss: 2.7471 - mae: 1.2455 - val_loss: 2.7628 - val_mae: 1.2372 - train_spearman_corr: 0.7451 - val_spearman_corr: 0.7262 - lr: 1.0000e-06
# Epoch 79/100
# 392/393 [============================>.] - ETA: 0s - loss: 2.7393 - mae: 1.2445
# Epoch 79: val_mae improved from 1.23633 to 1.23608, saving model to best_model.h5
# 6283/6283 [==============================] - 12s 2ms/step
# 1571/1571 [==============================] - 3s 2ms/step
# Epoch 79: Train Spearman Rank Correlation: 0.7452, Val Spearman Rank Correlation: 0.7262
# 393/393 [==============================] - 27s 69ms/step - loss: 2.7391 - mae: 1.2444 - val_loss: 2.7628 - val_mae: 1.2361 - train_spearman_corr: 0.7452 - val_spearman_corr: 0.7262 - lr: 1.0000e-06
# Epoch 80/100
# 393/393 [==============================] - ETA: 0s - loss: 2.7460 - mae: 1.2451
# Epoch 80: val_mae did not improve from 1.23608
# 6283/6283 [==============================] - 13s 2ms/step
# 1571/1571 [==============================] - 3s 2ms/step
# Epoch 80: Train Spearman Rank Correlation: 0.7452, Val Spearman Rank Correlation: 0.7262
# 393/393 [==============================] - 27s 69ms/step - loss: 2.7460 - mae: 1.2451 - val_loss: 2.7626 - val_mae: 1.2366 - train_spearman_corr: 0.7452 - val_spearman_corr: 0.7262 - lr: 1.0000e-06
# Epoch 81/100
# 390/393 [============================>.] - ETA: 0s - loss: 2.7432 - mae: 1.2449
# Epoch 81: val_mae did not improve from 1.23608
# 6283/6283 [==============================] - 13s 2ms/step
# 1571/1571 [==============================] - 3s 2ms/step
# Epoch 81: Train Spearman Rank Correlation: 0.7451, Val Spearman Rank Correlation: 0.7262
# 393/393 [==============================] - 27s 69ms/step - loss: 2.7433 - mae: 1.2450 - val_loss: 2.7626 - val_mae: 1.2373 - train_spearman_corr: 0.7451 - val_spearman_corr: 0.7262 - lr: 1.0000e-06
# Epoch 82/100
# 393/393 [==============================] - ETA: 0s - loss: 2.7411 - mae: 1.2445
# Epoch 82: val_mae did not improve from 1.23608
# 6283/6283 [==============================] - 13s 2ms/step
# 1571/1571 [==============================] - 3s 2ms/step
# Epoch 82: Train Spearman Rank Correlation: 0.7451, Val Spearman Rank Correlation: 0.7262
# 393/393 [==============================] - 27s 69ms/step - loss: 2.7411 - mae: 1.2445 - val_loss: 2.7628 - val_mae: 1.2380 - train_spearman_corr: 0.7451 - val_spearman_corr: 0.7262 - lr: 1.0000e-06
# Epoch 83/100
# 390/393 [============================>.] - ETA: 0s - loss: 2.7457 - mae: 1.2450
# Epoch 83: val_mae did not improve from 1.23608
# 6283/6283 [==============================] - 13s 2ms/step
# 1571/1571 [==============================] - 3s 2ms/step
# Epoch 83: Train Spearman Rank Correlation: 0.7452, Val Spearman Rank Correlation: 0.7263
# 393/393 [==============================] - 27s 70ms/step - loss: 2.7450 - mae: 1.2447 - val_loss: 2.7619 - val_mae: 1.2376 - train_spearman_corr: 0.7452 - val_spearman_corr: 0.7263 - lr: 1.0000e-06
# Epoch 84/100
# 393/393 [==============================] - ETA: 0s - loss: 2.7409 - mae: 1.2441
# Epoch 84: val_mae did not improve from 1.23608
# 6283/6283 [==============================] - 12s 2ms/step
# 1571/1571 [==============================] - 3s 2ms/step
# Epoch 84: Train Spearman Rank Correlation: 0.7452, Val Spearman Rank Correlation: 0.7263
# 393/393 [==============================] - 27s 69ms/step - loss: 2.7409 - mae: 1.2441 - val_loss: 2.7621 - val_mae: 1.2372 - train_spearman_corr: 0.7452 - val_spearman_corr: 0.7263 - lr: 1.0000e-06
# Epoch 85/100
# 390/393 [============================>.] - ETA: 0s - loss: 2.7458 - mae: 1.2458
# Epoch 85: val_mae did not improve from 1.23608
# 6283/6283 [==============================] - 13s 2ms/step
# 1571/1571 [==============================] - 3s 2ms/step
# Epoch 85: Train Spearman Rank Correlation: 0.7453, Val Spearman Rank Correlation: 0.7263
# 393/393 [==============================] - 27s 69ms/step - loss: 2.7453 - mae: 1.2457 - val_loss: 2.7620 - val_mae: 1.2362 - train_spearman_corr: 0.7453 - val_spearman_corr: 0.7263 - lr: 1.0000e-06
# Epoch 86/100
# 392/393 [============================>.] - ETA: 0s - loss: 2.7414 - mae: 1.2449
# Epoch 86: val_mae did not improve from 1.23608
# 6283/6283 [==============================] - 13s 2ms/step
# 1571/1571 [==============================] - 3s 2ms/step
# Epoch 86: Train Spearman Rank Correlation: 0.7452, Val Spearman Rank Correlation: 0.7263
# 393/393 [==============================] - 27s 70ms/step - loss: 2.7413 - mae: 1.2449 - val_loss: 2.7618 - val_mae: 1.2367 - train_spearman_corr: 0.7452 - val_spearman_corr: 0.7263 - lr: 1.0000e-06
# Epoch 87/100
# 392/393 [============================>.] - ETA: 0s - loss: 2.7419 - mae: 1.2448
# Epoch 87: val_mae did not improve from 1.23608
# 6283/6283 [==============================] - 12s 2ms/step
# 1571/1571 [==============================] - 3s 2ms/step
# Epoch 87: Train Spearman Rank Correlation: 0.7452, Val Spearman Rank Correlation: 0.7263
# 393/393 [==============================] - 27s 69ms/step - loss: 2.7421 - mae: 1.2449 - val_loss: 2.7620 - val_mae: 1.2374 - train_spearman_corr: 0.7452 - val_spearman_corr: 0.7263 - lr: 1.0000e-06
# Epoch 88/100
# 392/393 [============================>.] - ETA: 0s - loss: 2.7393 - mae: 1.2434
# Epoch 88: val_mae did not improve from 1.23608
# 6283/6283 [==============================] - 14s 2ms/step
# 1571/1571 [==============================] - 3s 2ms/step
# Epoch 88: Train Spearman Rank Correlation: 0.7453, Val Spearman Rank Correlation: 0.7264
# 393/393 [==============================] - 30s 77ms/step - loss: 2.7394 - mae: 1.2436 - val_loss: 2.7613 - val_mae: 1.2367 - train_spearman_corr: 0.7453 - val_spearman_corr: 0.7264 - lr: 1.0000e-06
# Epoch 89/100
# 391/393 [============================>.] - ETA: 0s - loss: 2.7416 - mae: 1.2448
# Epoch 89: val_mae did not improve from 1.23608
# 6283/6283 [==============================] - 12s 2ms/step
# 1571/1571 [==============================] - 3s 2ms/step
# Epoch 89: Train Spearman Rank Correlation: 0.7454, Val Spearman Rank Correlation: 0.7264
# 393/393 [==============================] - 27s 68ms/step - loss: 2.7408 - mae: 1.2447 - val_loss: 2.7610 - val_mae: 1.2362 - train_spearman_corr: 0.7454 - val_spearman_corr: 0.7264 - lr: 1.0000e-06
# Epoch 90/100
# 391/393 [============================>.] - ETA: 0s - loss: 2.7410 - mae: 1.2443Restoring model weights from the end of the best epoch: 79.
#
# Epoch 90: val_mae did not improve from 1.23608
# 6283/6283 [==============================] - 13s 2ms/step
# 1571/1571 [==============================] - 3s 2ms/step
# Epoch 90: Train Spearman Rank Correlation: 0.7452, Val Spearman Rank Correlation: 0.7262
# 393/393 [==============================] - 27s 69ms/step - loss: 2.7405 - mae: 1.2442 - val_loss: 2.7610 - val_mae: 1.2363 - train_spearman_corr: 0.7452 - val_spearman_corr: 0.7262 - lr: 1.0000e-06
# Epoch 90: early stopping

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 8))
plt.plot(history1.history['mae'], label='Training MAE')
plt.plot(history1.history['val_mae'], label='Validation MAE')
plt.title('Training and Validation MAE')
plt.ylabel('MAE')
plt.xlabel('Epochs')
plt.legend()
plt.show()

# %%
# Plot SRC
plt.figure(figsize=(12, 8))
plt.plot(history1.history['train_spearman_corr'], label='Training SRC')
plt.plot(history1.history['val_spearman_corr'], label='Validation SRC')
plt.title('Training and Validation SRC')
plt.ylabel('SRC')
plt.xlabel('Epochs')
plt.legend()
